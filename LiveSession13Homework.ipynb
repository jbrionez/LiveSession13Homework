# %%
my_list = [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]
#Print the 5th element in the list
print (my_list[4])
# Out:
# 39.0

# %%
#Append 55.2 to my_list
my_list.append(55.2)
print (my_list)
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %%
#Remove the 6th element in the list
my_list.pop(5)
print (my_list)
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %%
#Iterate over the list to print data points greater than 45
x = [i for i in my_list if i>45]
print(x)
# Out:
# [45.4, 47.4, 45.8, 55.2]

# %%
#Import the numpy library using the following command – import numpy
import numpy

# %%
#Declare numpy array with the same data points as in my_list using numpy.array()
numpy.array(my_list)
# Out:
# array([ 45.4,  44.2,  36.8,  35.1,  39. ,  47.4,  41.1,  45.8,  35.6,  55.2])

# %%
#Compute the mean and standard deviation using numpy.mean() and numpy.std() of the above array
numpy.mean(numpy.array(my_list))
# Out:
# 42.560000000000002

# %%
numpy.std(numpy.array(my_list))
# Out:
# 5.9709630713981143

# %%
#Use logical referencing to get only those values that are less than 45
numpy.where(numpy.array(my_list) < 45)
# Out:
# (array([1, 2, 3, 4, 6, 8], dtype=int64),)

# %%
#Compute the max and min of the array using numpy.max() and numpy.min()
numpy.max(numpy.array(my_list))
# Out:
# 55.200000000000003

# %%
numpy.min(numpy.array(my_list))
# Out:
# 35.100000000000001

# %%
#Import the pandas library – import pandas
import pandas as pd

# %%
#Read the IRIS dataset into iris using pandas.read_csv(). Data file – 
data = pd.read_csv("C:/Users/Jacob/.spyder-py3/iris.csv")
print(data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# 25    26            5.0           3.0            1.6           0.2
# 26    27            5.0           3.4            1.6           0.4
# 27    28            5.2           3.5            1.5           0.2
# 28    29            5.2           3.4            1.4           0.2
# 29    30            4.7           3.2            1.6           0.2
# ..   ...            ...           ...            ...           ...
# 120  121            6.9           3.2            5.7           2.3
# 121  122            5.6           2.8            4.9           2.0
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# 133  Iris-virginica
# 134  Iris-virginica
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#Using iris.head(), display the head of the dataset
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Use DataFrame.drop() to drop the id column
data=data.drop('Id', axis=1)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 10             5.4           3.7            1.5           0.2     Iris-setosa
# 11             4.8           3.4            1.6           0.2     Iris-setosa
# 12             4.8           3.0            1.4           0.1     Iris-setosa
# 13             4.3           3.0            1.1           0.1     Iris-setosa
# 14             5.8           4.0            1.2           0.2     Iris-setosa
# 15             5.7           4.4            1.5           0.4     Iris-setosa
# 16             5.4           3.9            1.3           0.4     Iris-setosa
# 17             5.1           3.5            1.4           0.3     Iris-setosa
# 18             5.7           3.8            1.7           0.3     Iris-setosa
# 19             5.1           3.8            1.5           0.3     Iris-setosa
# 20             5.4           3.4            1.7           0.2     Iris-setosa
# 21             5.1           3.7            1.5           0.4     Iris-setosa
# 22             4.6           3.6            1.0           0.2     Iris-setosa
# 23             5.1           3.3            1.7           0.5     Iris-setosa
# 24             4.8           3.4            1.9           0.2     Iris-setosa
# 25             5.0           3.0            1.6           0.2     Iris-setosa
# 26             5.0           3.4            1.6           0.4     Iris-setosa
# 27             5.2           3.5            1.5           0.2     Iris-setosa
# 28             5.2           3.4            1.4           0.2     Iris-setosa
# 29             4.7           3.2            1.6           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 120            6.9           3.2            5.7           2.3  Iris-virginica
# 121            5.6           2.8            4.9           2.0  Iris-virginica
# 122            7.7           2.8            6.7           2.0  Iris-virginica
# 123            6.3           2.7            4.9           1.8  Iris-virginica
# 124            6.7           3.3            5.7           2.1  Iris-virginica
# 125            7.2           3.2            6.0           1.8  Iris-virginica
# 126            6.2           2.8            4.8           1.8  Iris-virginica
# 127            6.1           3.0            4.9           1.8  Iris-virginica
# 128            6.4           2.8            5.6           2.1  Iris-virginica
# 129            7.2           3.0            5.8           1.6  Iris-virginica
# 130            7.4           2.8            6.1           1.9  Iris-virginica
# 131            7.9           3.8            6.4           2.0  Iris-virginica
# 132            6.4           2.8            5.6           2.2  Iris-virginica
# 133            6.3           2.8            5.1           1.5  Iris-virginica
# 134            6.1           2.6            5.6           1.4  Iris-virginica
# 135            7.7           3.0            6.1           2.3  Iris-virginica
# 136            6.3           3.4            5.6           2.4  Iris-virginica
# 137            6.4           3.1            5.5           1.8  Iris-virginica
# 138            6.0           3.0            4.8           1.8  Iris-virginica
# 139            6.9           3.1            5.4           2.1  Iris-virginica
# 140            6.7           3.1            5.6           2.4  Iris-virginica
# 141            6.9           3.1            5.1           2.3  Iris-virginica
# 142            5.8           2.7            5.1           1.9  Iris-virginica
# 143            6.8           3.2            5.9           2.3  Iris-virginica
# 144            6.7           3.3            5.7           2.5  Iris-virginica
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Subset dataframe to create a new data frame that includes only the measurements for the setosa species
data1=data[data.Species == 'Iris-setosa']
data1
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# 12            4.8           3.0            1.4           0.1  Iris-setosa
# 13            4.3           3.0            1.1           0.1  Iris-setosa
# 14            5.8           4.0            1.2           0.2  Iris-setosa
# 15            5.7           4.4            1.5           0.4  Iris-setosa
# 16            5.4           3.9            1.3           0.4  Iris-setosa
# 17            5.1           3.5            1.4           0.3  Iris-setosa
# 18            5.7           3.8            1.7           0.3  Iris-setosa
# 19            5.1           3.8            1.5           0.3  Iris-setosa
# 20            5.4           3.4            1.7           0.2  Iris-setosa
# 21            5.1           3.7            1.5           0.4  Iris-setosa
# 22            4.6           3.6            1.0           0.2  Iris-setosa
# 23            5.1           3.3            1.7           0.5  Iris-setosa
# 24            4.8           3.4            1.9           0.2  Iris-setosa
# 25            5.0           3.0            1.6           0.2  Iris-setosa
# 26            5.0           3.4            1.6           0.4  Iris-setosa
# 27            5.2           3.5            1.5           0.2  Iris-setosa
# 28            5.2           3.4            1.4           0.2  Iris-setosa
# 29            4.7           3.2            1.6           0.2  Iris-setosa
# 30            4.8           3.1            1.6           0.2  Iris-setosa
# 31            5.4           3.4            1.5           0.4  Iris-setosa
# 32            5.2           4.1            1.5           0.1  Iris-setosa
# 33            5.5           4.2            1.4           0.2  Iris-setosa
# 34            4.9           3.1            1.5           0.1  Iris-setosa
# 35            5.0           3.2            1.2           0.2  Iris-setosa
# 36            5.5           3.5            1.3           0.2  Iris-setosa
# 37            4.9           3.1            1.5           0.1  Iris-setosa
# 38            4.4           3.0            1.3           0.2  Iris-setosa
# 39            5.1           3.4            1.5           0.2  Iris-setosa
# 40            5.0           3.5            1.3           0.3  Iris-setosa
# 41            4.5           2.3            1.3           0.3  Iris-setosa
# 42            4.4           3.2            1.3           0.2  Iris-setosa
# 43            5.0           3.5            1.6           0.6  Iris-setosa
# 44            5.1           3.8            1.9           0.4  Iris-setosa
# 45            4.8           3.0            1.4           0.3  Iris-setosa
# 46            5.1           3.8            1.6           0.2  Iris-setosa
# 47            4.6           3.2            1.4           0.2  Iris-setosa
# 48            5.3           3.7            1.5           0.2  Iris-setosa
# 49            5.0           3.3            1.4           0.2  Iris-setosa

# %%
#Use DataFrame.describe() to get the summary statistics
data1.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %%
#Use DataFrame.groupby() to create grouped data frames by Species and compute summary statistics using DataFrame.describe()
data2 = data.groupby(['Species']) 
data2.describe()
# Out:
#                        PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# Species
# Iris-setosa     count      50.000000     50.000000      50.000000
#                 mean        1.464000      0.244000       5.006000
#                 std         0.173511      0.107210       0.352490
#                 min         1.000000      0.100000       4.300000
#                 25%         1.400000      0.200000       4.800000
#                 50%         1.500000      0.200000       5.000000
#                 75%         1.575000      0.300000       5.200000
#                 max         1.900000      0.600000       5.800000
# Iris-versicolor count      50.000000     50.000000      50.000000
#                 mean        4.260000      1.326000       5.936000
#                 std         0.469911      0.197753       0.516171
#                 min         3.000000      1.000000       4.900000
#                 25%         4.000000      1.200000       5.600000
#                 50%         4.350000      1.300000       5.900000
#                 75%         4.600000      1.500000       6.300000
#                 max         5.100000      1.800000       7.000000
# Iris-virginica  count      50.000000     50.000000      50.000000
#                 mean        5.552000      2.026000       6.588000
#                 std         0.551895      0.274650       0.635880
#                 min         4.500000      1.400000       4.900000
#                 25%         5.100000      1.800000       6.225000
#                 50%         5.550000      2.000000       6.500000
#                 75%         5.875000      2.300000       6.900000
#                 max         6.900000      2.500000       7.900000
#
#                        SepalWidthCm
# Species
# Iris-setosa     count     50.000000
#                 mean       3.418000
#                 std        0.381024
#                 min        2.300000
#                 25%        3.125000
#                 50%        3.400000
#                 75%        3.675000
#                 max        4.400000
# Iris-versicolor count     50.000000
#                 mean       2.770000
#                 std        0.313798
#                 min        2.000000
#                 25%        2.525000
#                 50%        2.800000
#                 75%        3.000000
#                 max        3.400000
# Iris-virginica  count     50.000000
#                 mean       2.974000
#                 std        0.322497
#                 min        2.200000
#                 25%        2.800000
#                 50%        3.000000
#                 75%        3.175000
#                 max        3.800000

# %%
#Use DataFrame.boxplot() to plot boxplots by Species
# %matplotlib inline
data2.boxplot()
# Out:
# C:\Users\Jacob\Anaconda3\lib\site-packages\pandas\tools\plotting.py:3082: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   rot=rot, grid=grid, **kwds)
# OrderedDict([('Iris-setosa',
#               {'boxes': [<matplotlib.lines.Line2D at 0x27ebf181cc0>,
#                 <matplotlib.lines.Line2D at 0x27ebef9d208>,
#                 <matplotlib.lines.Line2D at 0x27ebefa44e0>,
#                 <matplotlib.lines.Line2D at 0x27ebef28978>],
#                'caps': [<matplotlib.lines.Line2D at 0x27ebefbf3c8>,
#                 <matplotlib.lines.Line2D at 0x27ebefbf080>,
#                 <matplotlib.lines.Line2D at 0x27ebef31588>,
#                 <matplotlib.lines.Line2D at 0x27ebf184b00>,
#                 <matplotlib.lines.Line2D at 0x27ebef6d780>,
#                 <matplotlib.lines.Line2D at 0x27ebefc2da0>,
#                 <matplotlib.lines.Line2D at 0x27ebef71048>,
#                 <matplotlib.lines.Line2D at 0x27ebef52198>],
#                'fliers': [<matplotlib.lines.Line2D at 0x27ebefba2b0>,
#                 <matplotlib.lines.Line2D at 0x27ebf24c6a0>,
#                 <matplotlib.lines.Line2D at 0x27ebef79898>,
#                 <matplotlib.lines.Line2D at 0x27ebefa97b8>],
#                'means': [],
#                'medians': [<matplotlib.lines.Line2D at 0x27ebef69198>,
#                 <matplotlib.lines.Line2D at 0x27ebf157f28>,
#                 <matplotlib.lines.Line2D at 0x27ebefc2390>,
#                 <matplotlib.lines.Line2D at 0x27ebef48c50>],
#                'whiskers': [<matplotlib.lines.Line2D at 0x27ebf134c18>,
#                 <matplotlib.lines.Line2D at 0x27ebd8af518>,
#                 <matplotlib.lines.Line2D at 0x27ebefb6cf8>,
#                 <matplotlib.lines.Line2D at 0x27ebef5b438>,
#                 <matplotlib.lines.Line2D at 0x27ebefa46a0>,
#                 <matplotlib.lines.Line2D at 0x27ebefc88d0>,
#                 <matplotlib.lines.Line2D at 0x27ebef7da58>,
#                 <matplotlib.lines.Line2D at 0x27ebef7d0f0>]}),
#              ('Iris-versicolor',
#               {'boxes': [<matplotlib.lines.Line2D at 0x27ebf2b91d0>,
#                 <matplotlib.lines.Line2D at 0x27ebf1a7e10>,
#                 <matplotlib.lines.Line2D at 0x27ebef87f98>,
#                 <matplotlib.lines.Line2D at 0x27ebef9c7f0>],
#                'caps': [<matplotlib.lines.Line2D at 0x27ebf271f60>,
#                 <matplotlib.lines.Line2D at 0x27ebf1faac8>,
#                 <matplotlib.lines.Line2D at 0x27ebf448e48>,
#                 <matplotlib.lines.Line2D at 0x27ebf1bad30>,
#                 <matplotlib.lines.Line2D at 0x27ebef86e48>,
#                 <matplotlib.lines.Line2D at 0x27ebef86fd0>,
#                 <matplotlib.lines.Line2D at 0x27ebf2167b8>,
#                 <matplotlib.lines.Line2D at 0x27ebf216fd0>],
#                'fliers': [<matplotlib.lines.Line2D at 0x27ebf1a7b70>,
#                 <matplotlib.lines.Line2D at 0x27ebef87f28>,
#                 <matplotlib.lines.Line2D at 0x27ebef95fd0>,
#                 <matplotlib.lines.Line2D at 0x27ebf239f60>],
#                'means': [],
#                'medians': [<matplotlib.lines.Line2D at 0x27ebf1fa390>,
#                 <matplotlib.lines.Line2D at 0x27ebf1baeb8>,
#                 <matplotlib.lines.Line2D at 0x27ebef95828>,
#                 <matplotlib.lines.Line2D at 0x27ebf239198>],
#                'whiskers': [<matplotlib.lines.Line2D at 0x27ebf444470>,
#                 <matplotlib.lines.Line2D at 0x27ebef339e8>,
#                 <matplotlib.lines.Line2D at 0x27ebef754a8>,
#                 <matplotlib.lines.Line2D at 0x27ebf448080>,
#                 <matplotlib.lines.Line2D at 0x27ebef8edd8>,
#                 <matplotlib.lines.Line2D at 0x27ebef8ef60>,
#                 <matplotlib.lines.Line2D at 0x27ebf20f748>,
#                 <matplotlib.lines.Line2D at 0x27ebf20ff60>]}),
#              ('Iris-virginica',
#               {'boxes': [<matplotlib.lines.Line2D at 0x27ebf250358>,
#                 <matplotlib.lines.Line2D at 0x27ebf170080>,
#                 <matplotlib.lines.Line2D at 0x27ebf1629b0>,
#                 <matplotlib.lines.Line2D at 0x27ebf447320>],
#                'caps': [<matplotlib.lines.Line2D at 0x27ebf21df98>,
#                 <matplotlib.lines.Line2D at 0x27ebf223ef0>,
#                 <matplotlib.lines.Line2D at 0x27ebf16bef0>,
#                 <matplotlib.lines.Line2D at 0x27ebf15b860>,
#                 <matplotlib.lines.Line2D at 0x27ebf143978>,
#                 <matplotlib.lines.Line2D at 0x27ebf143b00>,
#                 <matplotlib.lines.Line2D at 0x27ebf44ec18>,
#                 <matplotlib.lines.Line2D at 0x27ebf456b00>],
#                'fliers': [<matplotlib.lines.Line2D at 0x27ebf174f60>,
#                 <matplotlib.lines.Line2D at 0x27ebf1628d0>,
#                 <matplotlib.lines.Line2D at 0x27ebf152b70>,
#                 <matplotlib.lines.Line2D at 0x27ebf45cb70>],
#                'means': [],
#                'medians': [<matplotlib.lines.Line2D at 0x27ebf1740b8>,
#                 <matplotlib.lines.Line2D at 0x27ebf15b9e8>,
#                 <matplotlib.lines.Line2D at 0x27ebf152358>,
#                 <matplotlib.lines.Line2D at 0x27ebf456c88>],
#                'whiskers': [<matplotlib.lines.Line2D at 0x27ebf2250b8>,
#                 <matplotlib.lines.Line2D at 0x27ebf21de80>,
#                 <matplotlib.lines.Line2D at 0x27ebf170f98>,
#                 <matplotlib.lines.Line2D at 0x27ebf16b7f0>,
#                 <matplotlib.lines.Line2D at 0x27ebf14c908>,
#                 <matplotlib.lines.Line2D at 0x27ebf14ca90>,
#                 <matplotlib.lines.Line2D at 0x27ebf447ba8>,
#                 <matplotlib.lines.Line2D at 0x27ebf44ea90>]})])

# %%
#Plot a scatter matrix plot using the seaborn library. Use the following to load and plot 
import seaborn as sns
sns.pairplot(data,hue='Species')
